# %% [markdown]
# <a href="https://colab.research.google.com/github/michelletran126/BTE320/blob/main/RockPaperScissor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

play = input('Do you want to play? ').strip().lower()

while play=='yes' and play!='no':
  computer = random.choice(['rock', 'paper', 'scissors'])
  user = input("User choice (rock, paper, scissors): ").strip().lower()

  if user == computer:
    print(f'User:{user}, Computer:{computer}')
    print('Draw')

  elif (
    (user == 'rock' and computer == 'scissors') or
    (user == 'scissors' and computer == 'paper') or
    (user == 'paper' and computer == 'rock')):
    print(f'User:{user}, Computer:{computer}')
    print('You win!')

  else:
    print(f'User:{user}, Computer:{computer}')
    print('Computer wins')

  play=input("Do you wish to continue?")
