# %% [markdown]
# <a href="https://colab.research.google.com/github/michelletran126/BTE320/blob/main/PointsandRectangles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Point:
  def __init__(self, x, y):
    self.x = x
    self.y = y

  def distance(self, other):
    return ((self.x - other.x) ** 2 + (self.y - other.y) ** 2) ** .5

class Rectangle:
  def __init__(self):
    self.p1 = Point(0,0)
    self.p2 = Point(4,0)
    self.p3 = Point(4,4)
    self.p4 = Point(0,4)
    self.width = self.p1.distance(self.p2)
    self.height = self.p2.distance(self.p3)

  def area(self):
    return self.width * self.height
