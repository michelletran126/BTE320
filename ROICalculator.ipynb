# %% [markdown]
# <a href="https://colab.research.google.com/github/michelletran126/BTE320/blob/main/ROICalculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def roi(cost:float, revenue: float) -> float:
  assert cost > 0, "Cost muct be positive"
  assert isinstance(cost, (int, float)), "Cost must be numerical"
  assert isinstance(revenue, (int, float)), "Revenue must be numerical"

  return (revenue - cost) / cost

if __name__ == "__main__":
  c = float(input("Enter the cost: "))
  r = float(input("Enter the revenue: "))
  ret = roi(c,r)
  print(ret)
