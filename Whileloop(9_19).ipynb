# %% [markdown]
# <a href="https://colab.research.google.com/github/michelletran126/BTE320/blob/main/Whileloop(9_19).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For loop movie theater

for ad in range(0, 201, 25):
  revenue = 10 * (20 + 2 * ad ** 0.5) - 200 - ad
  print(ad, round(revenue))
# Out:
# 0 0
# 25 75
# 50 91
# 75 98
# 100 100
# 125 99
# 150 95
# 175 90
# 200 83

# %%
for in range (11):
  if i % 2 !=0:
    continue
    print(i)
    # prints even numbers

# %%
# for
for i in range (100000000):
  if i == 3:
    break
  print(i)
# does not print 3 because when it equals 3 it exits out the code
# Out:
# 0
# 1
# 2

# %%
# Strings

a = "This is a string"

len(a)

# Index is 15 (n-1)
# Out:
# 16

# %%
# if you want to print the first i
a[2]
# Out:
# 'i'

# %%
# if you want to slice the word "is"

a[5:7]

# remember to skip to the number above and not land on 6
# Out:
# 'is'

# %%
a[0:len(a)]

#prints everything / returns the whole string
# Out:
# 'This is a string'

# %%
a[0:4]
# this is to print out "This"

# %%
a[10:len(a)]
# to print "string"
#len(a) is the default (length 16)

# %%
a[ : ]
# prints out the whole thing

# %%
a[ : ] == a[0:len*(a)] == a

# %%
for index in range(len(a)):
  if
